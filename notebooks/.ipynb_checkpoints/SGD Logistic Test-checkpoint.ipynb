# %%
import sys
sys.path.append('../')
from SGD import custom_SGD

# %% [markdown]
# ## Test with the single step for the gradient computation

# %%
custom_SGD.grad_logit_step_test()
# Out:
# Iter 0 theta: [ 0.79 -0.17 -1.13]
# Training Accuracy: 0.500
# Iter 1 theta: [1.24 1.62 2.02]
# Training Accuracy: 0.500
# Iter 2 theta: [ 0.79  0.72 -0.68]
# Training Accuracy: 0.500
# Iter 3 theta: [1.07 1.95 1.31]
# Training Accuracy: 0.500
# Iter 4 theta: [ 0.62  1.05 -1.39]
# Training Accuracy: 0.500
# Iter 5 theta: [1.06 2.83 1.73]
# Training Accuracy: 0.500
# Iter 6 theta: [ 0.61  1.93 -0.97]
# Training Accuracy: 1.000
# Iter 7 theta: [ 0.6   2.06 -0.98]
# Training Accuracy: 1.000
# Iter 8 theta: [ 0.54  2.06 -1.25]
# Training Accuracy: 1.000
# Iter 9 theta: [0.74 2.88 0.12]
# Training Accuracy: 0.500
# Iter 10 theta: [ 0.29  1.98 -2.58]
# Training Accuracy: 0.500
# Iter 11 theta: [0.74 3.78 0.57]
# Training Accuracy: 0.500
# Iter 12 theta: [ 0.29  2.88 -2.13]
# Training Accuracy: 0.500
# Iter 13 theta: [0.72 4.6  0.88]
# Training Accuracy: 0.500
# Iter 14 theta: [ 0.27  3.7  -1.82]
# Training Accuracy: 1.000
# Iter 15 theta: [ 0.29  3.83 -1.64]
# Training Accuracy: 1.000
# Iter 16 theta: [ 0.24  3.74 -1.93]
# Training Accuracy: 1.000
# Iter 17 theta: [ 0.3   4.01 -1.49]
# Training Accuracy: 1.000
# Iter 18 theta: [ 0.14  3.7  -2.44]
# Training Accuracy: 0.500
# Iter 19 theta: [0.55 5.3  0.38]
# Training Accuracy: 0.500
# Iter 20 theta: [ 0.1   4.4  -2.32]
# Training Accuracy: 1.000
# Iter 21 theta: [ 0.18  4.74 -1.74]
# Training Accuracy: 1.000
# Iter 22 theta: [ 0.04  4.46 -2.57]
# Training Accuracy: 0.500
# Iter 23 theta: [ 0.28  5.42 -0.91]
# Training Accuracy: 0.500
# Iter 24 theta: [-0.17  4.52 -3.6 ]
# Training Accuracy: 0.500
# Iter 25 theta: [ 0.28  6.32 -0.45]
# Training Accuracy: 0.500
# Iter 26 theta: [-0.17  5.42 -3.15]
# Training Accuracy: 0.500
# Iter 27 theta: [ 0.11  6.57 -1.14]
# Training Accuracy: 0.500
# Iter 28 theta: [-0.33  5.67 -3.84]
# Training Accuracy: 0.500
# Iter 29 theta: [ 0.11  7.45 -0.72]
# Training Accuracy: 0.500
# Iter 30 theta: [-0.34  6.55 -3.42]
# Training Accuracy: 1.000
# Iter 31 theta: [-0.28  6.78 -3.01]
# Training Accuracy: 1.000
# Iter 32 theta: [-0.28  6.78 -3.03]
# Training Accuracy: 1.000
# Iter 33 theta: [-0.28  6.78 -3.03]
# Training Accuracy: 1.000
# Iter 34 theta: [-0.29  6.78 -3.04]
# Training Accuracy: 1.000
# Iter 35 theta: [-0.29  6.78 -3.05]
# Training Accuracy: 1.000
# Iter 36 theta: [-0.29  6.78 -3.05]
# Training Accuracy: 1.000
# Iter 37 theta: [-0.29  6.78 -3.06]
# Training Accuracy: 1.000
# Iter 38 theta: [-0.29  6.79 -3.06]
# Training Accuracy: 1.000
# Iter 39 theta: [-0.29  6.79 -3.06]
# Training Accuracy: 1.000
# Iter 40 theta: [-0.29  6.79 -3.07]
# Training Accuracy: 1.000
# Iter 41 theta: [-0.29  6.79 -3.07]
# Training Accuracy: 1.000
# Iter 42 theta: [-0.29  6.8  -3.07]
# Training Accuracy: 1.000
# Iter 43 theta: [-0.29  6.8  -3.07]
# Training Accuracy: 1.000
# Iter 44 theta: [-0.29  6.8  -3.07]
# Training Accuracy: 1.000
# Iter 45 theta: [-0.3   6.8  -3.08]
# Training Accuracy: 1.000
# Iter 46 theta: [-0.3   6.81 -3.08]
# Training Accuracy: 1.000
# Iter 47 theta: [-0.3   6.81 -3.08]
# Training Accuracy: 1.000
# Iter 48 theta: [-0.3   6.81 -3.08]
# Training Accuracy: 1.000
# Iter 49 theta: [-0.3   6.82 -3.08]
# Training Accuracy: 1.000
# Predicted: [1.   0.01]
# Expected: [1. 0.]

# %% [markdown]
# ## Testing the binary classifier

# %%
custom_SGD.SGD_test_binary()
# Out:
# Full batch
# Number of samples: 455
# Number of parameters: 31
# It: 1 Batch: 1 Epoch 0 Train Acc : 0.37142857 lr: 0.01000000
# It: 100 Batch: 1 Epoch 99 Train Acc : 0.88571429 lr: 0.00031623
# It: 200 Batch: 1 Epoch 199 Train Acc : 0.89010989 lr: 0.00018803
# It: 300 Batch: 1 Epoch 299 Train Acc : 0.88571429 lr: 0.00013873
# It: 400 Batch: 1 Epoch 399 Train Acc : 0.88571429 lr: 0.00011180
# It: 500 Batch: 1 Epoch 499 Train Acc : 0.89450549 lr: 0.00009457
# ../SGD/custom_SGD.py:103: RuntimeWarning: overflow encountered in exp
#   h = 1 / (1 + np.exp(-dot))
# It: 600 Batch: 1 Epoch 599 Train Acc : 0.89670330 lr: 0.00008249
# It: 700 Batch: 1 Epoch 699 Train Acc : 0.89450549 lr: 0.00007348
# It: 800 Batch: 1 Epoch 799 Train Acc : 0.89670330 lr: 0.00006648
# It: 900 Batch: 1 Epoch 899 Train Acc : 0.89670330 lr: 0.00006086
# It: 1000 Batch: 1 Epoch 999 Train Acc : 0.89670330 lr: 0.00005623
# Finished
#  Whole Set Train Acc: 0.89670330
# Time Spent  2.666081218000002
# Validation Stats...
# Accuracy: 0.912
# Precision: 0.942
# Recall: 0.915
# F1 Score: 0.928571
# {0: 0, 1: 1}
# Confusion matrix, without normalization
# Normalized confusion matrix
# Stochastic Mini batch
# Number of samples: 455
# Number of parameters: 31
# Shuffled
# It: 1 Batch: 1 Epoch 0 Train Acc : 0.73437500 lr: 0.01000000
# It: 100 Batch: 4 Epoch 12 Train Acc : 0.96875000 lr: 0.00031623
# It: 200 Batch: 8 Epoch 24 Train Acc : 1.00000000 lr: 0.00018803
# It: 300 Batch: 4 Epoch 37 Train Acc : 0.87500000 lr: 0.00013873
# It: 400 Batch: 8 Epoch 49 Train Acc : 1.00000000 lr: 0.00011180
# It: 500 Batch: 4 Epoch 62 Train Acc : 0.92187500 lr: 0.00009457
# It: 600 Batch: 8 Epoch 74 Train Acc : 1.00000000 lr: 0.00008249
# It: 700 Batch: 4 Epoch 87 Train Acc : 0.85937500 lr: 0.00007348
# It: 800 Batch: 8 Epoch 99 Train Acc : 0.85714286 lr: 0.00006648
# It: 900 Batch: 4 Epoch 112 Train Acc : 0.90625000 lr: 0.00006086
# It: 1000 Batch: 8 Epoch 124 Train Acc : 0.57142857 lr: 0.00005623
# Finished
#  Whole Set Train Acc: 0.85274725
# Time Spent  0.25232441599999333
# Validation Stats...
# Accuracy: 0.921
# Precision: 0.984
# Recall: 0.887
# F1 Score: 0.933333
# {0: 0, 1: 1}
# Confusion matrix, without normalization
# Normalized confusion matrix
# Mini batch
# Number of samples: 455
# Number of parameters: 31
# It: 1 Batch: 1 Epoch 0 Train Acc : 0.32812500 lr: 0.01000000
# It: 100 Batch: 4 Epoch 12 Train Acc : 0.93750000 lr: 0.00031623
# It: 200 Batch: 8 Epoch 24 Train Acc : 1.00000000 lr: 0.00018803
# It: 300 Batch: 4 Epoch 37 Train Acc : 0.93750000 lr: 0.00013873
# It: 400 Batch: 8 Epoch 49 Train Acc : 1.00000000 lr: 0.00011180
# It: 500 Batch: 4 Epoch 62 Train Acc : 0.93750000 lr: 0.00009457
# It: 600 Batch: 8 Epoch 74 Train Acc : 1.00000000 lr: 0.00008249
# It: 700 Batch: 4 Epoch 87 Train Acc : 0.93750000 lr: 0.00007348
# It: 800 Batch: 8 Epoch 99 Train Acc : 1.00000000 lr: 0.00006648
# It: 900 Batch: 4 Epoch 112 Train Acc : 0.93750000 lr: 0.00006086
# It: 1000 Batch: 8 Epoch 124 Train Acc : 1.00000000 lr: 0.00005623
# Finished
#  Whole Set Train Acc: 0.88791209
# Time Spent  0.23836522700000273
# Validation Stats...
# Accuracy: 0.921
# Precision: 0.956
# Recall: 0.915
# F1 Score: 0.935252
# {0: 0, 1: 1}
# Confusion matrix, without normalization
# Normalized confusion matrix
# Single Instance
# Number of samples: 455
# Number of parameters: 31
# It: 1 Batch: 1 Epoch 0 Train Acc : 1.00000000 lr: 0.01000000
# It: 100 Batch: 100 Epoch 0 Train Acc : 1.00000000 lr: 0.00031623
# It: 200 Batch: 200 Epoch 0 Train Acc : 1.00000000 lr: 0.00018803
# It: 300 Batch: 300 Epoch 0 Train Acc : 1.00000000 lr: 0.00013873
# It: 400 Batch: 400 Epoch 0 Train Acc : 1.00000000 lr: 0.00011180
# It: 500 Batch: 45 Epoch 1 Train Acc : 1.00000000 lr: 0.00009457
# It: 600 Batch: 145 Epoch 1 Train Acc : 1.00000000 lr: 0.00008249
# It: 700 Batch: 245 Epoch 1 Train Acc : 1.00000000 lr: 0.00007348
# It: 800 Batch: 345 Epoch 1 Train Acc : 1.00000000 lr: 0.00006648
# It: 900 Batch: 445 Epoch 1 Train Acc : 1.00000000 lr: 0.00006086
# It: 1000 Batch: 90 Epoch 2 Train Acc : 1.00000000 lr: 0.00005623
# Finished
#  Whole Set Train Acc: 0.89890110
# Time Spent  0.2035288419999972
# (114,) (114,)
# Validation Stats...
# Accuracy: 0.930
# Precision: 0.920
# Recall: 0.972
# F1 Score: 0.945205
# {0: 0, 1: 1}
# Confusion matrix, without normalization
# Normalized confusion matrix

# %% [markdown]
# ## Testing One against all Classification for multiclass

# %%
custom_SGD.SGD_test_multiclass('default')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-d828c9408168> in <module>()
# ----> 1 custom_SGD.SGD_test_multiclass()
#
# TypeError: SGD_test_multiclass() missing 1 required positional argument: 'scaling_type'

# %%
import numpy as np
np.where(np.random.rand(10) > 0.5, 1, 0)
# Out:
# array([1, 1, 0, 0, 0, 1, 0, 0, 0, 0])
