# %% [markdown]
# # Cross Validation - Round 2
# ## Multinomial Logistic Regression (Softmax Regression)
# This notebook performs the 5-fold Cross Validation Gridsearch to find the best hyperparameters for the Multinomial Logistic Regression. The hyperparameters tested are:
#  * Learning rate: 0.1 and 0.01,
#  * Number of iterations: 5000 and 10000.

# %%
import sys
sys.path.append('../')
import SGD
from SGD import softmax_logistic
from SGD.experiments import *
from sklearn.model_selection import train_test_split

from utils import dataset_helper
from importlib import reload
from scipy import stats
import pandas as pd
reload(dataset_helper)
# Out:
# /home/azael/Trabalhos/MO444/MO444/lib/python3.5/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# <module 'utils.dataset_helper' from '../utils/dataset_helper.py'>

# %%
X, y, _, _  = dataset_helper.load_fasion_mnist(scaling='default')
   
#X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=1)

params=[{'lr':0.1,'max_iter':5000},
        {'lr':0.01,'max_iter':5000},
        {'lr':0.1,'max_iter':10000},
        {'lr':0.01,'max_iter':10000}]

nfolds = 5
classifier = 'softmax'

score = crossValidation(X,y,nfolds,params,classifier)

print(score)
df_score = pd.DataFrame(score)
df_score
# Out:
# ...
#  K-Fold Cross Validation Grid Search
#  Params:
# {'max_iter': 5000, 'lr': 0.1}
# {'max_iter': 5000, 'lr': 0.01}
# {'max_iter': 10000, 'lr': 0.1}
# {'max_iter': 10000, 'lr': 0.01}
# ...
# Testing params:
# lr = 0.1
# it = 5000
# ----- Fold 0
# Samples: 48000
# Features: 785
# Iteration: 0 Cost= 2.0766414574655894
# Iteration: 100 Cost= 0.7081390164516097
# Iteration: 200 Cost= 0.6174914319945806
# Iteration: 300 Cost= 0.5745179014113565
# Iteration: 400 Cost= 0.5479661911713011
# Iteration: 500 Cost= 0.5294144187362755
# Iteration: 600 Cost= 0.515471601709355
# Iteration: 700 Cost= 0.5044698163796887
# Iteration: 800 Cost= 0.49548132192460526
# Iteration: 900 Cost= 0.48794427244654553
# Iteration: 1000 Cost= 0.4814960846251798
# Iteration: 1100 Cost= 0.4758908175258219
# Iteration: 1200 Cost= 0.47095480819298297
# Iteration: 1300 Cost= 0.4665613124672399
# Iteration: 1400 Cost= 0.4626152486073827
# Iteration: 1500 Cost= 0.45904361526414483
# Iteration: 1600 Cost= 0.45578924753255873
# ...
